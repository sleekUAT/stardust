# %%
ls
# Out:
# stardustt/

# %%
ls ../../
# Out:
# apps/

# %%
../../../
# Out:
#   Cell In[3], line 1
#     ../../../
#     ^
# SyntaxError: invalid syntax

# %%
ls ../../../
# Out:
# ou/  ubuntu/

# %%
ls ../../
# Out:
# apps/

# %%
ls ../../apps
# Out:
# __main__.py    aws_acc.txt    notes.ipynb    supervisord.conf  tools_dev.py
# archives/      awscliv2.zip*  py3_venv/      supervisord.log   tools_nb.ipynb
# archives.zip*  logs.db        some_notes.md  supervisord.pid   untitled.txt
# aws/           nohup.out      stardust/      tools.py
